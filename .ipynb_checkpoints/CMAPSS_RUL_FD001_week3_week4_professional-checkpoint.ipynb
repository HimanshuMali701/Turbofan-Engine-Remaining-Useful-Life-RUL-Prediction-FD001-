# %% [markdown]
# # Turbofan Engine RUL Prediction — FD001
#
# Professional week-by-week notebook with headings and interpretations.

# %% [markdown]
# ## Setup & Instructions
#
# Set DATA_DIR to the folder containing the dataset files before running. This notebook includes Week-3 (preprocessing) and Week-4 (modeling) sections.

# %%
import os
print('Set DATA_DIR = \'/mnt/data\' or your local path before running this notebook')
